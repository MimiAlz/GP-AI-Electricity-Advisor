# %%
import pandas as pd
import numpy as np

# %%
data = {
    'A': np.random.randint(1, 100, 10),
    'B': np.random.rand(10),
    'C': ['foo', 'bar'] * 5
}

# %%
df=pd.DataFrame(data)

# %%
df
# Out:
#     A         B    C
# 0   6  0.048300  foo
# 1   1  0.527717  bar
# 2   1  0.624585  foo
# 3  62  0.386580  bar
# 4  45  0.005810  foo
# 5  58  0.815062  bar
# 6  15  0.004453  foo
# 7   1  0.165116  bar
# 8  75  0.139453  foo
# 9  38  0.530351  bar
